# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

# Your dataset URL
url = "https://s3.ap-south-1.amazonaws.com/production-mentormind/resources/files/000/005/818/original/Dataset_e-shop_clothing.csv?1722328461"

# Read using the correct delimiter
df = pd.read_csv(url, sep=';')

# Preview the fixed DataFrame
df.head()
# Out:
#    year  month  day  order  country  session ID  page 1 (main category)  \
# 0  2008      4    1      1       29           1                       1
# 1  2008      4    1      2       29           1                       1
# 2  2008      4    1      3       29           1                       2
# 3  2008      4    1      4       29           1                       2
# 4  2008      4    1      5       29           1                       2
#
#   page 2 (clothing model)  colour  location  model photography  price  \
# 0                     A13       1         5                  1     28
# 1                     A16       1         6                  1     33
# 2                      B4      10         2                  1     52
# 3                     B17       6         6                  2     38
# 4                      B8       4         3                  2     52
#
#    price 2  page
# 0        2     1
# 1        2     1
# 2        1     1
# 3        2     1
# 4        1     1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165474 entries, 0 to 165473
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   year                     165474 non-null  int64
#  1   month                    165474 non-null  int64
#  2   day                      165474 non-null  int64
#  3   order                    165474 non-null  int64
#  4   country                  165474 non-null  int64
#  5   session ID               165474 non-null  int64
#  6   page 1 (main category)   165474 non-null  int64
#  7   page 2 (clothing model)  165474 non-null  object
#  8   colour                   165474 non-null  int64
#  9   location                 165474 non-null  int64
#  10  model photography        165474 non-null  int64
#  11  price                    165474 non-null  int64
#  12  price 2                  165474 non-null  int64
#  13  page                     165474 non-null  int64
# dtypes: int64(13), object(1)
# memory usage: 17.7+ MB

# %%
df.describe(include='all')
# Out:
#             year          month            day          order        country  \
# count   165474.0  165474.000000  165474.000000  165474.000000  165474.000000
# unique       NaN            NaN            NaN            NaN            NaN
# top          NaN            NaN            NaN            NaN            NaN
# freq         NaN            NaN            NaN            NaN            NaN
# mean      2008.0       5.585887      14.524554       9.817476      26.952621
# std          0.0       1.328160       8.830374      13.478411       7.150691
# min       2008.0       4.000000       1.000000       1.000000       1.000000
# 25%       2008.0       4.000000       7.000000       2.000000      29.000000
# 50%       2008.0       5.000000      14.000000       6.000000      29.000000
# 75%       2008.0       7.000000      22.000000      12.000000      29.000000
# max       2008.0       8.000000      31.000000     195.000000      47.000000
#
#            session ID  page 1 (main category) page 2 (clothing model)  \
# count   165474.000000           165474.000000                  165474
# unique            NaN                     NaN                     217
# top               NaN                     NaN                      B4
# freq              NaN                     NaN                    3579
# mean     12058.417056                2.400842                     NaN
# std       7008.418903                1.144420                     NaN
# min          1.000000                1.000000                     NaN
# 25%       5931.000000                1.000000                     NaN
# 50%      11967.500000                2.000000                     NaN
# 75%      18219.000000                3.000000                     NaN
# max      24026.000000                4.000000                     NaN
#
#                colour       location  model photography          price  \
# count   165474.000000  165474.000000      165474.000000  165474.000000
# unique            NaN            NaN                NaN            NaN
# top               NaN            NaN                NaN            NaN
# freq              NaN            NaN                NaN            NaN
# mean         6.227655       3.258198           1.260071      43.802507
# std          4.235606       1.713206           0.438674      12.548131
# min          1.000000       1.000000           1.000000      18.000000
# 25%          3.000000       2.000000           1.000000      33.000000
# 50%          4.000000       3.000000           1.000000      43.000000
# 75%          9.000000       5.000000           2.000000      52.000000
# max         14.000000       6.000000           2.000000      82.000000
#
#               price 2           page
# count   165474.000000  165474.000000
# unique            NaN            NaN
# top               NaN            NaN
# freq              NaN            NaN
# mean         1.488167       1.710166
# std          0.499861       0.982412
# min          1.000000       1.000000
# 25%          1.000000       1.000000
# 50%          1.000000       1.000000
# 75%          2.000000       2.000000
# max          2.000000       5.000000

# %%
df.columns
# Out:
# Index(['year', 'month', 'day', 'order', 'country', 'session ID',
#        'page 1 (main category)', 'page 2 (clothing model)', 'colour',
#        'location', 'model photography', 'price', 'price 2', 'page'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# year                       0
# month                      0
# day                        0
# order                      0
# country                    0
# session ID                 0
# page 1 (main category)     0
# page 2 (clothing model)    0
# colour                     0
# location                   0
# model photography          0
# price                      0
# price 2                    0
# page                       0
# dtype: int64

# %%
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# %%
df['date'] = pd.to_datetime(df[['year', 'month', 'day']])

# %%
df.drop_duplicates(inplace=True)
